# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
output_dir = "./frames/"

cap = cv2.VideoCapture("./test.mp4")
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

frame_count = 0
while True:
    frame_ready, frame = cap.read()  # Read the frame
    if not frame_ready:
        print("End of video or error reading frame.")
        break

    # Convert to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    #plt.imshow(gray_frame, cmap='gray')
    #plt.show()

    #print(gray_frame.shape)

    # Save frame as a numpy array
    frame_path = os.path.join(output_dir, f"frame_{frame_count:04d}.npy")
    np.save(frame_path, gray_frame)

    frame_count += 1

    # Show progress
    print(f"Processed frame {frame_count}")

    # Exit on key press (optional)
    if cv2.waitKey(10) == 27:  # Escape key
        break

cap.release()
print(f"Frames saved in directory: {output_dir}")
# Out:
# Processed frame 1
# Processed frame 2
# Processed frame 3
# Processed frame 4
# Processed frame 5
# Processed frame 6
# Processed frame 7
# Processed frame 8
# Processed frame 9
# Processed frame 10
# Processed frame 11
# Processed frame 12
# Processed frame 13
# Processed frame 14
# Processed frame 15
# Processed frame 16
# Processed frame 17
# Processed frame 18
# Processed frame 19
# Processed frame 20
# Processed frame 21
# Processed frame 22
# Processed frame 23
# Processed frame 24
# Processed frame 25
# Processed frame 26
# Processed frame 27
# Processed frame 28
# Processed frame 29
# Processed frame 30
# Processed frame 31
# Processed frame 32
# Processed frame 33
# Processed frame 34
# Processed frame 35
# Processed frame 36
# Processed frame 37
# Processed frame 38
# Processed frame 39
# Processed frame 40
# Processed frame 41
# Processed frame 42
# Processed frame 43
# Processed frame 44
# Processed frame 45
# Processed frame 46
# Processed frame 47
# Processed frame 48
# Processed frame 49
# Processed frame 50
# Processed frame 51
# Processed frame 52
# Processed frame 53
# Processed frame 54
# Processed frame 55
# Processed frame 56
# Processed frame 57
# Processed frame 58
# Processed frame 59
# Processed frame 60
# Processed frame 61
# Processed frame 62
# Processed frame 63
# Processed frame 64
# Processed frame 65
# Processed frame 66
# Processed frame 67
# Processed frame 68
# Processed frame 69
# Processed frame 70
# Processed frame 71
# Processed frame 72
# Processed frame 73
# Processed frame 74
# Processed frame 75
# Processed frame 76
# Processed frame 77
# Processed frame 78
# Processed frame 79
# Processed frame 80
# Processed frame 81
# Processed frame 82
# Processed frame 83
# Processed frame 84
# Processed frame 85
# Processed frame 86
# Processed frame 87
# Processed frame 88
# Processed frame 89
# Processed frame 90
# Processed frame 91
# Processed frame 92
# Processed frame 93
# Processed frame 94
# Processed frame 95
# Processed frame 96
# Processed frame 97
# Processed frame 98
# Processed frame 99
# Processed frame 100
# Processed frame 101
# Processed frame 102
# Processed frame 103
# Processed frame 104
# Processed frame 105
# Processed frame 106
# Processed frame 107
# Processed frame 108
# Processed frame 109
# Processed frame 110
# Processed frame 111
# Processed frame 112
# Processed frame 113
# Processed frame 114
# Processed frame 115
# Processed frame 116
# Processed frame 117
# Processed frame 118
# Processed frame 119
# Processed frame 120
# Processed frame 121
# Processed frame 122
# Processed frame 123
# Processed frame 124
# Processed frame 125
# Processed frame 126
# Processed frame 127
# Processed frame 128
# Processed frame 3426
# Processed frame 3427
# Processed frame 3428
# Processed frame 3429
# Processed frame 3430
# Processed frame 3431
# Processed frame 3432
# End of video or error reading frame.
# Frames saved in directory: ./frames/

# %%
from PIL import Image, ImageDraw, ImageFont

def ascii_to_image(ascii_art, font_path='cour.ttf', font_size=12, bg_color='black', text_color='white'):
    """
    Converts a 2D list (or list of strings) of ASCII characters into an image.
    Adjust font_path to point to a monospaced font on your system (e.g., Courier).
    """
    # Ensure ascii_art is a list of strings (each row)
    if isinstance(ascii_art[0], list):
        ascii_art = ["".join(row) for row in ascii_art]
    
    # Determine the size of the image.
    # Here, we assume each character takes roughly (font_size, font_size) pixels.
    rows = len(ascii_art)
    cols = max(len(row) for row in ascii_art)
    image_width = cols * font_size
    image_height = rows * font_size
    
    image = Image.new("RGB", (image_width, image_height), color=bg_color)
    draw = ImageDraw.Draw(image)
    
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print("Could not load font, using default.")
        font = ImageFont.load_default()
    
    y = 0
    for line in ascii_art:
        draw.text((0, y), line, fill=text_color, font=font)
        y += font_size
    return image

# %%
# Define or import the load_ascii_mappings function if not already defined:
def load_ascii_mappings(ascii_csv_path):
    import numpy as np
    import pandas as pd
    df = pd.read_csv(ascii_csv_path)
    ascii_mappings = {
        3: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_3']],
        5: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_5']],
        7: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_7']],
    }
    ascii_chars = df['char'].to_numpy()
    return ascii_mappings, ascii_chars

# Set the path to your CSV file containing the ASCII mappings
ascii_csv_path = "./ascii_characters_roman.csv"

# Load the mappings and characters
ascii_mappings, ascii_chars = load_ascii_mappings(ascii_csv_path)
# Out:
# /tmp/ipykernel_542439/4219830921.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def process_frame(image, ascii_mappings, ascii_chars, num_col_patches=80, pca_size=5):
    if image.ndim != 2:
        raise ValueError("Input image must be a grayscale image.")

    original_a, original_b = image.shape  # Original height and width

    # Aspect ratio adjustment
    multiplier = (original_b * num_col_patches) / original_a
    k = round(multiplier)
    resized_b = num_col_patches * k
    resized_a = (original_a / original_b) * resized_b
    resized_a = round(resized_a / k) * k

    resized_image = cv2.resize(image, (int(resized_b), int(resized_a)))

    # Optional visualization block (commented or wrapped in try/except)
    try:
        resized_resized_image = cv2.resize(resized_image, (int(resized_b // k), int(resized_a // k)))
        print("Visualization image shape:", resized_resized_image.shape)
        # plt.imshow(resized_resized_image, cmap='gray')
        # plt.show()
    except Exception as e:
        print("Visualization skipped:", e)

    # Extract patches using the helper function
    patches, rows, cols = extract_patches(resized_image, k)
    
    # Correctly call calculate_ascii with all required arguments
    ascii_result = calculate_ascii(patches, pca_size, ascii_mappings, ascii_chars)
    
    # Convert the ASCII result to a 2D list
    processed_image = np.array(ascii_result).reshape(rows, cols).tolist()
    print("Processed frame to ASCII art, shape:", (rows, cols))
    
    return processed_image

# %%
import numpy as np
from sklearn.decomposition import PCA
import sys

def extract_patches(image, patch_size):
    """
    Extract patches from the image.
    
    Args:
        image (np.ndarray): Grayscale image array.
        patch_size (int): The size (height and width) of each patch.
    
    Returns:
        patches (list): List of flattened patches.
        rows (int): Number of patch rows.
        cols (int): Number of patch columns.
    """
    a, b = image.shape
    if a % patch_size != 0 or b % patch_size != 0:
        raise ValueError("Image dimensions must be divisible by patch size.")
    
    patches = [image[i:i+patch_size, j:j+patch_size].flatten()
               for i in range(0, a, patch_size)
               for j in range(0, b, patch_size)]
    return patches, a // patch_size, b // patch_size

def calculate_ascii(patches, pca_size, ascii_mappings, ascii_chars):
    """
    Calculate ASCII values for patches using PCA.
    
    Args:
        patches (list): List of flattened image patches.
        pca_size (int): Number of PCA components.
        ascii_mappings (dict): Mapping of PCA components to ASCII vector values.
        ascii_chars (np.ndarray): Array of ASCII characters.
    
    Returns:
        ascii_result (list): List of ASCII characters corresponding to each patch.
    """
    pca = PCA(n_components=pca_size)
    patches_pca = pca.fit_transform(patches)
    ascii_result = []
    for patch in patches_pca:
        min_dist = sys.maxsize
        min_char = None
        # Use the ascii mapping for the given PCA size
        for i, ascii_vec in enumerate(ascii_mappings[pca_size]):
            dist = np.linalg.norm(patch - ascii_vec)
            if dist < min_dist:
                min_dist = dist
                min_char = chr(ascii_chars[i])
        ascii_result.append(min_char)
    return ascii_result

# %%
import cv2
import numpy as np
import os

# Example function definitions (make sure these are defined or imported properly)
# def load_ascii_mappings(...): ...
# def process_frame(...): ...
# def ascii_to_image(...): ...

# Load your ASCII mappings
ascii_csv_path = "./ascii_characters_roman.csv"
ascii_mappings, ascii_chars = load_ascii_mappings(ascii_csv_path)

# Define the directory where frames are stored and output directory for ASCII images
input_dir = "./frames"
ascii_output_dir = "./ascii_frames"
os.makedirs(ascii_output_dir, exist_ok=True)

# For demonstration, try loading a single frame file (adjust the filename as needed)
frame_file = "frame_0000.npy"
frame_path = os.path.join(input_dir, frame_file)

try:
    frame = np.load(frame_path)
except Exception as e:
    print(f"Error loading {frame_path}: {e}")
    frame = None

if frame is None:
    print(f"Warning: Frame loaded from {frame_path} is None. Please check your input files.")
else:
    # Process the frame into ASCII art
    ascii_art = process_frame(frame, ascii_mappings, ascii_chars, num_col_patches=80, pca_size=5)
    # Convert ASCII art to an image (make sure to have a valid monospaced font file, e.g., 'cour.ttf')
    image = ascii_to_image(ascii_art, font_path='cour.ttf', font_size=12)
    # Save the image
    image_save_path = os.path.join(ascii_output_dir, f"{os.path.splitext(frame_file)[0]}.png")
    image.save(image_save_path)
    print(f"Saved ASCII art image to {image_save_path}")
# Out:
# Visualization image shape: (45, 80)
# /home/sushovan/.local/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:640: RuntimeWarning: divide by zero encountered in divide
#   self.explained_variance_ratio_ = self.explained_variance_ / total_var
# /home/sushovan/.local/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:640: RuntimeWarning: invalid value encountered in divide
#   self.explained_variance_ratio_ = self.explained_variance_ / total_var
# Processed frame to ASCII art, shape: (45, 80)
# Could not load font, using default.
# Saved ASCII art image to ./ascii_frames/frame_0000.png

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
from sklearn.decomposition import PCA
import sys

##############################
# Helper Functions and Setup #
##############################

def load_ascii_mappings(ascii_csv_path):
    """
    Load ASCII mappings and character list from a CSV file.
    The CSV is assumed to have columns: 'pca_3', 'pca_5', 'pca_7', and 'char'.
    Each row for pca_n should look like [0.1 0.2 0.3 ...].
    """
    df = pd.read_csv(ascii_csv_path)

    # Convert string representations like "[0.1 0.2 0.3]" into numpy arrays.
    ascii_mappings = {
        3: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_3']],
        5: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_5']],
        7: [np.fromstring(row.strip('[]'), sep=' ') for row in df['pca_7']],
    }
    # 'char' is expected to contain the numeric ASCII code or the actual character.
    # If it's a numeric ASCII code, use `chr(ascii_chars[i])` when mapping.
    ascii_chars = df['char'].to_numpy()
    return ascii_mappings, ascii_chars

def extract_patches(image, patch_size):
    """
    Divide the image into non-overlapping patches of size patch_size x patch_size.
    Returns a list of flattened patches and the number of patch rows and columns.
    """
    a, b = image.shape
    if a % patch_size != 0 or b % patch_size != 0:
        raise ValueError("Image dimensions must be divisible by patch size.")
    patches = [image[i:i+patch_size, j:j+patch_size].flatten()
               for i in range(0, a, patch_size)
               for j in range(0, b, patch_size)]
    return patches, a // patch_size, b // patch_size

def calculate_ascii(patches, pca_size, ascii_mappings, ascii_chars):
    """
    For each flattened patch, use PCA to reduce its dimension and map it to an ASCII character
    by finding the closest precomputed ASCII vector.
    """
    # Perform PCA on the patches
    pca = PCA(n_components=pca_size)
    patches_pca = pca.fit_transform(patches)

    ascii_result = []
    for patch in patches_pca:
        min_dist = float('inf')
        min_char = None

        # Compare the patch's PCA vector to each known ASCII PCA vector
        for i, ascii_vec in enumerate(ascii_mappings[pca_size]):
            dist = np.linalg.norm(patch - ascii_vec)
            if dist < min_dist:
                min_dist = dist
                # If 'char' column is numeric (ASCII code), convert to character with chr().
                # If 'char' column is already a character, use it directly: ascii_chars[i].
                try:
                    min_char = chr(int(ascii_chars[i]))
                except ValueError:
                    min_char = str(ascii_chars[i])  # if it's already a string/char
        ascii_result.append(min_char)
    return ascii_result

def process_frame(image, ascii_mappings, ascii_chars, num_col_patches=80, pca_size=5):
    """
    Process a single grayscale frame into a 2D ASCII art representation.
    The image is first resized based on the desired number of column patches.
    """
    if image.ndim != 2:
        raise ValueError("Input image must be a grayscale image.")

    original_a, original_b = image.shape

    # Determine a patch size (k) based on the desired number of column patches.
    # multiplier is how many pixels we want per patch in the "width" dimension.
    # This is a heuristic: (original_b * num_col_patches) / original_a
    multiplier = (original_b * num_col_patches) / original_a
    k = round(multiplier)
    
    # The new width = number of columns * patch_size
    resized_b = num_col_patches * k
    # The new height is scaled proportionally
    resized_a_float = (original_a / original_b) * resized_b
    # Make sure resized_a is divisible by k
    resized_a = round(resized_a_float / k) * k

    # Resize the image for processing (OpenCV expects integer dimensions)
    resized_image = cv2.resize(image, (int(resized_b), int(resized_a)))

    # Optional visualization (for debugging purposes)
    try:
        # Create a smaller version for quick preview (1 patch = 1 pixel).
        vis_img = cv2.resize(
            resized_image, 
            (int(resized_b // k), int(resized_a // k)),
            interpolation=cv2.INTER_NEAREST
        )
        print("Visualization image shape (rows x cols):", vis_img.shape)
        # Uncomment the next two lines to see the visualization:
        # plt.imshow(vis_img, cmap='gray')
        # plt.show()
    except Exception as e:
        print("Visualization skipped:", e)

    # Divide the resized image into patches and compute ASCII mapping.
    patches, rows, cols = extract_patches(resized_image, k)
    ascii_result = calculate_ascii(patches, pca_size, ascii_mappings, ascii_chars)
    
    # Convert the linear list into a 2D list (rows x cols)
    processed_image = np.array(ascii_result).reshape(rows, cols).tolist()
    print("Processed frame to ASCII art, shape (rows, cols):", (rows, cols))
    return processed_image

def ascii_to_image_centered(
    ascii_art,
    output_dir,
    frame_name,
    font_path='cour.ttf',
    font_size=12,
    bg_color='black',
    text_color='white',
    char_spacing_str="  "):
    """
    Convert a 2D ASCII art (list of lists or list of strings) into a properly centered image
    and also save the ASCII text file and the image in output_dir using frame_name as the base.
    """

    # If ascii_art is a 2D list, join each row into a string
    if isinstance(ascii_art[0], list):
        ascii_art = ["".join(row) for row in ascii_art]
    
    # Optionally insert spacing between characters (e.g., "  ")
    spaced_ascii_art = []
    for line in ascii_art:
        spaced_line = char_spacing_str.join(list(line))
        spaced_ascii_art.append(spaced_line)
    ascii_art = spaced_ascii_art
    
    # Calculate text dimensions
    rows = len(ascii_art)
    cols = max(len(line) for line in ascii_art)
    
    # This is a heuristic for approximate width/height.
    # Each character is ~ (font_size/2) wide in many monospaced fonts.
    image_width = cols * (font_size // 2)  
    image_height = rows * font_size
    
    # Add padding so the text isn't right on the border
    padding_x = font_size * 2
    padding_y = font_size * 2
    
    # Create a new image for the ASCII art
    image = Image.new(
        mode="RGB",
        size=(image_width + 2 * padding_x, image_height + 2 * padding_y),
        color=bg_color
    )
    draw = ImageDraw.Draw(image)
    
    # Attempt to load custom font. If it fails, use default.
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print("Could not load font at '{}'. Using default font.".format(font_path))
        font = ImageFont.load_default()
    
    # Draw each line, centered horizontally
    y_cursor = padding_y
    for line in ascii_art:
        text_width = draw.textlength(line, font=font)
        # Center horizontally
        x_cursor = (image_width - text_width) // 2 + padding_x
        draw.text((x_cursor, y_cursor), line, fill=text_color, font=font)
        y_cursor += font_size
    
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Save ASCII text to file
    ascii_text_path = os.path.join(output_dir, f"{frame_name}.txt")
    with open(ascii_text_path, "w", encoding="utf-8") as f:
        f.write("\n".join(ascii_art))
    print(f"ASCII text saved to {ascii_text_path}")
    
    # Save ASCII image
    ascii_image_path = os.path.join(output_dir, f"{frame_name}.png")
    image.save(ascii_image_path)
    print(f"ASCII image saved to {ascii_image_path}")
    
    return image

###########################################
# Main Loop: Process All 20-Second Frames #
###########################################

def main():
    # Adjust paths as needed
    input_dir = "./frames"                # Folder containing .npy frames
    ascii_output_dir = "./ascii_frames"   # Where ASCII images and text files will go
    ascii_csv_path = "./ascii_characters_roman.csv"  # CSV with PCA vectors and chars

    # Create the output directory if needed
    os.makedirs(ascii_output_dir, exist_ok=True)

    # Load the ASCII mappings
    ascii_mappings, ascii_chars = load_ascii_mappings(ascii_csv_path)

    # Get a sorted list of all .npy frame files
    frame_files = sorted([f for f in os.listdir(input_dir) if f.endswith('.npy')])

    for frame_file in frame_files:
        frame_path = os.path.join(input_dir, frame_file)
        
        # Load the frame (assumed to be a grayscale image saved as a numpy array)
        try:
            frame = np.load(frame_path)
        except Exception as e:
            print(f"Error loading {frame_path}: {e}")
            continue
        
        if frame is None:
            print(f"Warning: Frame loaded from {frame_path} is None. Skipping.")
            continue
        
        # Derive a name for saving results (e.g., "frame_0001")
        frame_name = os.path.splitext(frame_file)[0]
        
        # Process the frame into ASCII art (you can tweak num_col_patches, pca_size)
        ascii_art = process_frame(frame, ascii_mappings, ascii_chars, 
                                  num_col_patches=80, pca_size=5)
        
        # Convert the ASCII art to an image and also save the .txt and .png
        image = ascii_to_image_centered(
            ascii_art, 
            output_dir=ascii_output_dir, 
            frame_name=frame_name,
            font_path='cour.ttf',         # Change to a valid TTF on your system
            font_size=12, 
            bg_color='black', 
            text_color='white',
            char_spacing_str="  "
        )
        
        print(f"Finished processing: {frame_file}")

if __name__ == "__main__":
    main()
# Out:
# Visualization image shape (rows x cols): (45, 80)
# /home/sushovan/.local/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:640: RuntimeWarning: divide by zero encountered in divide
#   self.explained_variance_ratio_ = self.explained_variance_ / total_var
# /home/sushovan/.local/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:640: RuntimeWarning: invalid value encountered in divide
#   self.explained_variance_ratio_ = self.explained_variance_ / total_var
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0000.txt
# ASCII image saved to ./ascii_frames/frame_0000.png
# Finished processing: frame_0000.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0001.txt
# ASCII image saved to ./ascii_frames/frame_0001.png
# Finished processing: frame_0001.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0002.txt
# ASCII image saved to ./ascii_frames/frame_0002.png
# Finished processing: frame_0002.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0003.txt
# ASCII image saved to ./ascii_frames/frame_0003.png
# Finished processing: frame_0003.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0004.txt
# ASCII image saved to ./ascii_frames/frame_0004.png
# Finished processing: frame_0004.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0005.txt
# ASCII image saved to ./ascii_frames/frame_0005.png
# Finished processing: frame_0005.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0006.txt
# ASCII image saved to ./ascii_frames/frame_0006.png
# Finished processing: frame_0006.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0007.txt
# ASCII image saved to ./ascii_frames/frame_0007.png
# Finished processing: frame_0007.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0008.txt
# ASCII image saved to ./ascii_frames/frame_0008.png
# Finished processing: frame_0008.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0009.txt
# ASCII image saved to ./ascii_frames/frame_0009.png
# Finished processing: frame_0009.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0010.txt
# ASCII image saved to ./ascii_frames/frame_0010.png
# Finished processing: frame_0010.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0011.txt
# ASCII image saved to ./ascii_frames/frame_0011.png
# Finished processing: frame_0011.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0012.txt
# ASCII image saved to ./ascii_frames/frame_0012.png
# Finished processing: frame_0012.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_
npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0046.txt
# ASCII image saved to ./ascii_frames/frame_0046.png
# Finished processing: frame_0046.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0047.txt
# ASCII image saved to ./ascii_frames/frame_0047.png
# Finished processing: frame_0047.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0048.txt
# ASCII image saved to ./ascii_frames/frame_0048.png
# Finished processing: frame_0048.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0049.txt
# ASCII image saved to ./ascii_frames/frame_0049.png
# Finished processing: frame_0049.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0050.txt
# ASCII image saved to ./ascii_frames/frame_0050.png
# Finished processing: frame_0050.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0051.txt
# ASCII image saved to ./ascii_frames/frame_0051.png
# Finished processing: frame_0051.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0052.txt
# ASCII image saved to ./ascii_frames/frame_0052.png
# Finished processing: frame_0052.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0053.txt
# ASCII image saved to ./ascii_frames/frame_0053.png
# Finished processing: frame_0053.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0054.txt
# ASCII image saved to ./ascii_frames/frame_0054.png
# Finished processing: frame_0054.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0055.txt
# ASCII image saved to ./ascii_frames/frame_0055.png
# Finished processing: frame_0055.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0056.txt
# ASCII image saved to ./ascii_frames/frame_0056.png
# Finished processing: frame_0056.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0057.txt
# ASCII image saved to ./ascii_frames/frame_0057.png
# Finished processing: frame_0057.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0058.txt
# ASCII image saved to ./ascii_frames/frame_0058.png
# Finished processing: frame_0058.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0059.txt
# ASCII image saved to ./ascii_frames/frame_0059.png
# Finished processing: frame_0059.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0060.txt
# ASCII image saved to ./ascii_frames/frame_0060.png
# Finished processing: frame_0060.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0061.txt
# ASCII image saved to ./ascii_frames/frame_0061.png
# Finished processing: frame_0061.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0062.txt
# ASCII image saved to ./ascii_frames/frame_0062.png
# Finished processing: frame_0062.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0063.txt
# ASCII image saved to ./ascii_frames/frame_0063.png
# Finished processing: frame_0063.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0064.txt
# ASCII image saved to ./ascii_frames/frame_0064.png
# Finished processing: frame_0064.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0065.txt
# ASCII image saved to ./ascii_frames/frame_0065.png
# Finished processing: frame_0065.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0066.txt
# ASCII image saved to ./ascii_frames/frame_0066.png
# Finished processing: frame_0066.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0067.txt
# ASCII image saved to ./ascii_frames/frame_0067.png
# Finished processing: frame_0067.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0068.txt
# ASCII image saved to ./ascii_frames/frame_0068.png
# Finished processing: frame_0068.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0069.txt
# ASCII image saved to ./ascii_frames/frame_0069.png
# Finished processing: frame_0069.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0070.txt
# ASCII image saved to ./ascii_frames/frame_0070.png
# Finished processing: frame_0070.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0071.txt
# ASCII image saved to ./ascii_frames/frame_0071.png
# Finished processing: frame_0071.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0072.txt
# ASCII image saved to ./ascii_frames/frame_0072.png
# Finished processing: frame_0072.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0073.txt
# ASCII image saved to ./ascii_frames/frame_0073.png
# Finished processing: frame_0073.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0074.txt
# ASCII image saved to ./ascii_frames/frame_0074.png
# Finished processing: frame_0074.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0075.txt
# ASCII image saved to ./ascii_frames/frame_0075.png
# Finished processing: frame_0075.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0076.txt
# ASCII image saved to ./ascii_frames/frame_0076.png
# Finished processing: frame_0076.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0077.txt
# ASCII image saved to ./ascii_frames/frame_0077.png
# Finished processing: frame_0077.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0078.txt
# ASCII image saved to ./ascii_frames/frame_0078.png
# Finished processing: frame_0078.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0079.txt
# ASCII image saved to ./ascii_frames/frame_0079.png
# Finished processing: frame_0079.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0080.txt
# ASCII image saved to ./ascii_frames/frame_0080.png
# Finished processing: frame_0080.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0081.txt
# ASCII image saved to ./ascii_frames/frame_0081.png
# Finished processing: frame_0081.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0082.txt
# ASCII image saved to ./ascii_frames/frame_0082.png
# Finished processing: frame_0082.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0083.txt
# ASCII image saved to ./ascii_frames/frame_0083.png
# Finished processing: frame_0083.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0084.txt
# ASCII image saved to ./ascii_frames/frame_0084.png
# Finished processing: frame_0084.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0085.txt
# ASCII image saved to ./ascii_frames/frame_0085.png
# Finished processing: frame_0085.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0086.txt
# ASCII image saved to ./ascii_frames/frame_0086.png
# Finished processing: frame_0086.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0087.txt
# ASCII image saved to ./ascii_frames/frame_0087.png
# Finished processing: frame_0087.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0088.txt
# ASCII image saved to ./ascii_frames/frame_0088.png
# Finished processing: frame_0088.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0089.txt
# ASCII image saved to ./ascii_frames/frame_0089.png
# Finished processing: frame_0089.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0090.txt
# ASCII image saved to ./ascii_frames/frame_0090.png
# Finished processing: frame_0090.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0091.txt
# ASCII image saved to ./ascii_frames/frame_0091.png
# Finished processing: frame_0091.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0092.txt
# ASCII image saved to ./ascii_frames/frame_0092.png
# Finished processing: frame_0092.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0093.txt
# ASCII image saved to ./ascii_frames/frame_0093.png
# Finished processing: frame_0093.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0094.txt
# ASCII image saved to ./ascii_frames/frame_0094.png
# Finished processing: frame_0094.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0095.txt
# ASCII image saved to ./ascii_frames/frame_0095.png
# Finished processing: frame_0095.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0096.txt
# ASCII image saved to ./ascii_frames/frame_0096.png
# Finished processing: frame_0096.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0097.txt
# ASCII image saved to ./ascii_frames/frame_0097.png
# Finished processing: frame_0097.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0098.txt
# ASCII image saved to ./ascii_frames/frame_0098.png
# Finished processing: frame_0098.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0099.txt
# ASCII image saved to ./ascii_frames/frame_0099.png
# Finished processing: frame_0099.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0100.txt
# ASCII image saved to ./ascii_frames/frame_0100.png
# Finished processing: frame_0100.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0101.txt
# ASCII image saved to ./ascii_frames/frame_0101.png
# Finished processing: frame_0101.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0102.txt
# ASCII image saved to ./ascii_frames/frame_0102.png
# Finished processing: frame_0102.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0103.txt
# ASCII image saved to ./ascii_frames/frame_0103.png
# Finished processing: frame_0103.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0104.txt
# ASCII image saved to ./ascii_frames/frame_0104.png
# Finished processing: frame_0104.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0105.txt
# ASCII image saved to ./ascii_frames/frame_0105.png
# Finished processing: frame_0105.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0106.txt
# ASCII image saved to ./ascii_frames/frame_0106.png
# Finished processing: frame_0106.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0107.txt
# ASCII image saved to ./ascii_frames/frame_0107.png
# Finished processing: frame_0107.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0108.txt
# ASCII image saved to ./ascii_frames/frame_0108.png
# Finished processing: frame_0108.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0109.txt
# ASCII image saved to ./ascii_frames/frame_0109.png
# Finished processing: frame_0109.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0110.txt
# ASCII image saved to ./ascii_frames/frame_0110.png
# Finished processing: frame_0110.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0111.txt
# ASCII image saved to ./ascii_frames/frame_0111.png
# Finished processing: frame_0111.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0112.txt
# ASCII image saved to ./ascii_frames/frame_0112.png
# Finished processing: frame_0112.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0113.txt
# ASCII image saved to ./ascii_frames/frame_0113.png
# Finished processing: frame_0113.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0114.txt
# ASCII image saved to ./ascii_frames/frame_0114.png
# Finished processing: frame_0114.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0115.txt
# ASCII image saved to ./ascii_frames/frame_0115.png
# Finished processing: frame_0115.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0116.txt
# ASCII image saved to ./ascii_frames/frame_0116.png
# Finished processing: frame_0116.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0117.txt
# ASCII image saved to ./ascii_frames/frame_0117.png
# Finished processing: frame_0117.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0118.txt
# ASCII image saved to ./ascii_frames/frame_0118.png
# Finished processing: frame_0118.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0119.txt
# ASCII image saved to ./ascii_frames/frame_0119.png
# Finished processing: frame_0119.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0120.txt
# ASCII image saved to ./ascii_frames/frame_0120.png
# Finished processing: frame_0120.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0121.txt
# ASCII image saved to ./ascii_frames/frame_0121.png
# Finished processing: frame_0121.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0122.txt
# ASCII image saved to ./ascii_frames/frame_0122.png
# Finished processing: frame_0122.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0123.txt
# ASCII image saved to ./ascii_frames/frame_0123.png
# Finished processing: frame_0123.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0124.txt
# ASCII image saved to ./ascii_frames/frame_0124.png
# Finished processing: frame_0124.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0125.txt
# ASCII image saved to ./ascii_frames/frame_0125.png
# Finished processing: frame_0125.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0126.txt
# ASCII image saved to ./ascii_frames/frame_0126.png
# Finished processing: frame_0126.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0127.txt
# ASCII image saved to ./ascii_frames/frame_0127.png
# Finished processing: frame_0127.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0128.txt
# ASCII image saved to ./ascii_frames/frame_0128.png
# Finished processing: frame_0128.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0129.txt
# ASCII image saved to ./ascii_frames/frame_0129.png
# Finished processing: frame_0129.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0130.txt
# ASCII image saved to ./ascii_frames/frame_0130.png
# Finished processing: frame_0130.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0131.txt
# ASCII image saved to ./ascii_frames/frame_0131.png
# Finished processing: frame_0131.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0132.txt
# ASCII image saved to ./ascii_frames/frame_0132.png
# Finished processing: frame_0132.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0133.txt
# ASCII image saved to ./ascii_frames/frame_0133.png
# Finished processing: frame_0133.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0134.txt
# ASCII image saved to ./ascii_frames/frame_0134.png
# Finished processing: frame_0134.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0135.txt
# ASCII image saved to ./ascii_frames/frame_0135.png
# Finished processing: frame_0135.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0136.txt
# ASCII image saved to ./ascii_frames/frame_0136.png
# Finished processing: frame_0136.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0137.txt
# ASCII image saved to ./ascii_frames/frame_0137.png
# Finished processing: frame_0137.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0138.txt
# ASCII image saved to ./ascii_frames/frame_0138.png
# Finished processing: frame_0138.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0139.txt
# ASCII image saved to ./ascii_frames/frame_0139.png
# Finished processing: frame_0139.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0140.txt
# ASCII image saved to ./ascii_frames/frame_0140.png
# Finished processing: frame_0140.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0141.txt
# ASCII image saved to ./ascii_frames/frame_0141.png
# Finished processing: frame_0141.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0142.txt
# ASCII image saved to ./ascii_frames/frame_0142.png
# Finished processing: frame_0142.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0143.txt
# ASCII image saved to ./ascii_frames/frame_0143.png
# Finished processing: frame_0143.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0144.txt
# ASCII image saved to ./ascii_frames/frame_0144.png
# Finished processing: frame_0144.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0145.txt
# ASCII image saved to ./ascii_frames/frame_0145.png
# Finished processing: frame_0145.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0146.txt
# ASCII image saved to ./ascii_frames/frame_0146.png
# Finished processing: frame_0146.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0147.txt
# ASCII image saved to ./ascii_frames/frame_0147.png
# Finished processing: frame_0147.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0148.txt
# ASCII image saved to ./ascii_frames/frame_0148.png
# Finished processing: frame_0148.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0149.txt
# ASCII image saved to ./ascii_frames/frame_0149.png
# Finished processing: frame_0149.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0150.txt
# ASCII image saved to ./ascii_frames/frame_0150.png
# Finished processing: frame_0150.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0151.txt
# ASCII image saved to ./ascii_frames/frame_0151.png
# Finished processing: frame_0151.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0152.txt
# ASCII image saved to ./ascii_frames/frame_0152.png
# Finished processing: frame_0152.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0153.txt
# ASCII image saved to ./ascii_frames/frame_0153.png
# Finished processing: frame_0153.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0154.txt
# ASCII image saved to ./ascii_frames/frame_0154.png
# Finished processing: frame_0154.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0155.txt
# ASCII image saved to ./ascii_frames/frame_0155.png
# Finished processing: frame_0155.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0156.txt
# ASCII image saved to ./ascii_frames/frame_0156.png
# Finished processing: frame_0156.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_0157.txt
# ASCII image saved to ./ascii_frames/frame_0157.png
# Finished processing: frame_0157.npy
# ...
# Finished processing: frame_3378.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3379.txt
# ASCII image saved to ./ascii_frames/frame_3379.png
# Finished processing: frame_3379.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3380.txt
# ASCII image saved to ./ascii_frames/frame_3380.png
# Finished processing: frame_3380.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3381.txt
# ASCII image saved to ./ascii_frames/frame_3381.png
# Finished processing: frame_3381.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3382.txt
# ASCII image saved to ./ascii_frames/frame_3382.png
# Finished processing: frame_3382.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3383.txt
# ASCII image saved to ./ascii_frames/frame_3383.png
# Finished processing: frame_3383.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3384.txt
# ASCII image saved to ./ascii_frames/frame_3384.png
# Finished processing: frame_3384.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3385.txt
# ASCII image saved to ./ascii_frames/frame_3385.png
# Finished processing: frame_3385.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3386.txt
# ASCII image saved to ./ascii_frames/frame_3386.png
# Finished processing: frame_3386.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3387.txt
# ASCII image saved to ./ascii_frames/frame_3387.png
# Finished processing: frame_3387.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3388.txt
# ASCII image saved to ./ascii_frames/frame_3388.png
# Finished processing: frame_3388.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3389.txt
# ASCII image saved to ./ascii_frames/frame_3389.png
# Finished processing: frame_3389.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3390.txt
# ASCII image saved to ./ascii_frames/frame_3390.png
# Finished processing: frame_3390.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3391.txt
# ASCII image saved to ./ascii_frames/frame_3391.png
# Finished processing: frame_3391.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3392.txt
# ASCII image saved to ./ascii_frames/frame_3392.png
# Finished processing: frame_3392.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3393.txt
# ASCII image saved to ./ascii_frames/frame_3393.png
# Finished processing: frame_3393.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3394.txt
# ASCII image saved to ./ascii_frames/frame_3394.png
# Finished processing: frame_3394.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3395.txt
# ASCII image saved to ./ascii_frames/frame_3395.png
# Finished processing: frame_3395.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3396.txt
# ASCII image saved to ./ascii_frames/frame_3396.png
# Finished processing: frame_3396.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3397.txt
# ASCII image saved to ./ascii_frames/frame_3397.png
# Finished processing: frame_3397.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3398.txt
# ASCII image saved to ./ascii_frames/frame_3398.png
# Finished processing: frame_3398.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3399.txt
# ASCII image saved to ./ascii_frames/frame_3399.png
# Finished processing: frame_3399.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3400.txt
# ASCII image saved to ./ascii_frames/frame_3400.png
# Finished processing: frame_3400.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3401.txt
# ASCII image saved to ./ascii_frames/frame_3401.png
# Finished processing: frame_3401.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3402.txt
# ASCII image saved to ./ascii_frames/frame_3402.png
# Finished processing: frame_3402.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3403.txt
# ASCII image saved to ./ascii_frames/frame_3403.png
# Finished processing: frame_3403.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3404.txt
# ASCII image saved to ./ascii_frames/frame_3404.png
# Finished processing: frame_3404.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3405.txt
# ASCII image saved to ./ascii_frames/frame_3405.png
# Finished processing: frame_3405.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3406.txt
# ASCII image saved to ./ascii_frames/frame_3406.png
# Finished processing: frame_3406.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3407.txt
# ASCII image saved to ./ascii_frames/frame_3407.png
# Finished processing: frame_3407.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3408.txt
# ASCII image saved to ./ascii_frames/frame_3408.png
# Finished processing: frame_3408.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3409.txt
# ASCII image saved to ./ascii_frames/frame_3409.png
# Finished processing: frame_3409.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3410.txt
# ASCII image saved to ./ascii_frames/frame_3410.png
# Finished processing: frame_3410.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3411.txt
# ASCII image saved to ./ascii_frames/frame_3411.png
# Finished processing: frame_3411.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3412.txt
# ASCII image saved to ./ascii_frames/frame_3412.png
# Finished processing: frame_3412.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3413.txt
# ASCII image saved to ./ascii_frames/frame_3413.png
# Finished processing: frame_3413.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3414.txt
# ASCII image saved to ./ascii_frames/frame_3414.png
# Finished processing: frame_3414.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3415.txt
# ASCII image saved to ./ascii_frames/frame_3415.png
# Finished processing: frame_3415.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3416.txt
# ASCII image saved to ./ascii_frames/frame_3416.png
# Finished processing: frame_3416.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3417.txt
# ASCII image saved to ./ascii_frames/frame_3417.png
# Finished processing: frame_3417.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3418.txt
# ASCII image saved to ./ascii_frames/frame_3418.png
# Finished processing: frame_3418.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3419.txt
# ASCII image saved to ./ascii_frames/frame_3419.png
# Finished processing: frame_3419.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3420.txt
# ASCII image saved to ./ascii_frames/frame_3420.png
# Finished processing: frame_3420.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3421.txt
# ASCII image saved to ./ascii_frames/frame_3421.png
# Finished processing: frame_3421.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3422.txt
# ASCII image saved to ./ascii_frames/frame_3422.png
# Finished processing: frame_3422.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3423.txt
# ASCII image saved to ./ascii_frames/frame_3423.png
# Finished processing: frame_3423.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3424.txt
# ASCII image saved to ./ascii_frames/frame_3424.png
# Finished processing: frame_3424.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3425.txt
# ASCII image saved to ./ascii_frames/frame_3425.png
# Finished processing: frame_3425.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3426.txt
# ASCII image saved to ./ascii_frames/frame_3426.png
# Finished processing: frame_3426.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3427.txt
# ASCII image saved to ./ascii_frames/frame_3427.png
# Finished processing: frame_3427.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3428.txt
# ASCII image saved to ./ascii_frames/frame_3428.png
# Finished processing: frame_3428.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3429.txt
# ASCII image saved to ./ascii_frames/frame_3429.png
# Finished processing: frame_3429.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3430.txt
# ASCII image saved to ./ascii_frames/frame_3430.png
# Finished processing: frame_3430.npy
# Visualization image shape (rows x cols): (45, 80)
# Processed frame to ASCII art, shape (rows, cols): (45, 80)
# Could not load font at 'cour.ttf'. Using default font.
# ASCII text saved to ./ascii_frames/frame_3431.txt
# ASCII image saved to ./ascii_frames/frame_3431.png
# Finished processing: frame_3431.npy

# %%
import os
import cv2
import ffmpeg
import numpy as np

def extract_audio_ffmpeg(input_video_path, audio_output_path):
    """
    Extracts audio from a video file using FFmpeg.
    """
    try:
        (
            ffmpeg
            .input(input_video_path)
            .output(audio_output_path, format="mp3", acodec="mp3")
            .run(overwrite_output=True, quiet=True)
        )
        print(f"✅ Extracted audio saved to: {audio_output_path}")
    except ffmpeg.Error as e:
        print(f"❌ FFmpeg Error: {e}")

def create_video_from_frames_opencv(frames_dir, output_video_path, fps=23.5):
    """
    Creates a video from PNG frames using OpenCV.
    """
    frame_files = sorted([
        f for f in os.listdir(frames_dir) if f.lower().endswith('.png')
    ])

    if not frame_files:
        raise ValueError(f"❌ No PNG frames found in {frames_dir}")

    first_frame = cv2.imread(os.path.join(frames_dir, frame_files[0]))
    height, width, _ = first_frame.shape

    # Define the video writer
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    for frame_file in frame_files:
        frame_path = os.path.join(frames_dir, frame_file)
        frame = cv2.imread(frame_path)
        if frame is None:
            print(f"⚠️ Warning: Could not read {frame_path}, skipping.")
            continue
        video_writer.write(frame)

    video_writer.release()
    print(f"✅ Video saved to: {output_video_path}")

def merge_video_audio_ffmpeg(video_path, audio_path, output_final_video):
    """
    Merges video and audio using FFmpeg.
    """
    try:
        # Properly define video and audio inputs separately
        video_input = ffmpeg.input(video_path)
        audio_input = ffmpeg.input(audio_path)

        # Merge them into a single output
        (
            ffmpeg
            .output(video_input, audio_input, output_final_video, vcodec="libx264", acodec="aac", strict="experimental")
            .run(overwrite_output=True, quiet=True)
        )
        print(f"✅ Final video with audio saved to: {output_final_video}")
    except ffmpeg.Error as e:
        print(f"❌ FFmpeg Error: {e}")

if __name__ == "__main__":
    # Paths (adjust as needed)
    original_video_path = "test.mp4"
    extracted_audio_path = "extracted_audio.mp3"
    ascii_frames_dir = "./ascii_frames"
    silent_video_path = "ascii_video_silent.mp4"
    output_video_path = "ascii_with_audio.mp4"
    fps = 23.4  # Adjust frame rate as needed

    # Step 1: Extract audio from the original video
    extract_audio_ffmpeg(original_video_path, extracted_audio_path)

    # Step 2: Create a video from the ASCII frames (silent video)
    create_video_from_frames_opencv(ascii_frames_dir, silent_video_path, fps)

    # Step 3: Merge silent video and extracted audio
    merge_video_audio_ffmpeg(silent_video_path, extracted_audio_path, output_video_path)

    print(f"🎉 Finished! The final video is saved to: {output_video_path}")
# Out:
# ✅ Extracted audio saved to: extracted_audio.mp3
# ✅ Video saved to: ascii_video_silent.mp4
# ✅ Final video with audio saved to: ascii_with_audio.mp4
# 🎉 Finished! The final video is saved to: ascii_with_audio.mp4
