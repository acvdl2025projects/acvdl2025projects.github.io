# %%
from asg1_3_v1 import mp4_ascii
# Out:
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v1.py:12: SyntaxWarning: invalid escape sequence '\|'
#   self.grey70 = "$@B%8&WM#*oahkbdpqwmZO0QLCJUYXzcvunxrjft/\|()1{}[]?-_+~<>i!lI;:,\"^‘’. "

# %%
Video = "./bleach_lr.mp4"

# %%
obj1 = mp4_ascii(160)

# %%
obj1.split_audio(Video)
obj1.vid_frames(Video)
# Out:
# Deleted existing file: ./bleach_lr.mp3
# Audio extracted successfully!
# video_fps: 23.9759088223852
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 obj1.split_audio(Video)
# ----> 2 obj1.vid_frames(Video)
#
# File c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v1.py:56, in mp4_ascii.vid_frames(self, video_path)
#      54 # Loop through each frame
#      55 while True:
# ---> 56     ret, frame = cap.read()
#      57     # Break the loop if no frame is returned (end of video)
#      58     if not ret:
#
# KeyboardInterrupt:

# %%
obj1.initialize()
obj1.frame2ascii()
obj1.compressVid()
obj1.vidWithAud()
# Out:
# Real Shape of Img: (1080, 1920)
# Scaled Ratio of the IMG: 12
# Dimension of New IMG: 90 x 160
# Patch size Dimension: 12 X 12
# Total frames: 3432
# Video created successfully!
# Video compressed successfully!
# Video with audio saved as ./bleach_lr/ascii_video/final_video.mp4

# %%
obj1.fullwork(Video)
# Out:
# Deleted existing file: ./bleach_lr.mp3
# Audio extracted successfully!
# video_fps: 23.97937293729373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 obj1.fullwork(Video)
#
# File c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v1.py:249, in mp4_ascii.fullwork(self, video_path)
#     247 def fullwork(self, video_path):
#     248     self.split_audio(video_path)
# --> 249     self.vid_frames(video_path)
#     250     self.initialize()
#     251     self.frame2ascii()
#
# File c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v1.py:61, in mp4_ascii.vid_frames(self, video_path)
#      59     break
#      60 frame_filename = os.path.join(frame_folder, f"frame_{frame_count:06d}.png")
# ---> 61 cv.imwrite(frame_filename, frame)
#      62 # print(f"Saved: {frame_filename}")
#      63 frame_count += 1
#
# KeyboardInterrupt:

# %%
from asg1_3_v2 import mp4_ascii2

# %%
obj2 = mp4_ascii2(160)

# %%
obj2.split_audio(Video)
# Out:
# Deleted existing file: ./bleach_lr.mp3
# Audio extracted successfully!

# %%
obj2.vid_frames(Video)
# Out:
# video_fps: 23.97937293729373
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v2.py:12: SyntaxWarning: invalid escape sequence '\|'
#   self.grey70 = "$@B%8&WM#*oahkbdpqwmZO0QLCJUYXzcvunxrjft/\|()1{}[]?-_+~<>i!lI;:,\"^‘’. "
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 obj2.vid_frames(Video)
#
# File c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\asg1_3_check\asg1_3_v2.py:63, in mp4_ascii2.vid_frames(self, video_path)
#      61     break
#      62 frame_filename = os.path.join(frame_folder, f"frame_{frame_count:06d}.png")
# ---> 63 cv.imwrite(frame_filename, frame)
#      64 # print(f"Saved: {frame_filename}")
#      65 frame_count += 1
#
# KeyboardInterrupt:

# %%
obj2.initialize()
# Out:
# Real Shape of Img: (1080, 1920)
# Scaled Ratio of the IMG: 12
# Dimension of New IMG: 90 x 160
# Patch size Dimension: 12 X 12
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}¡¢£¤¥¦§¨©ª«¬­®¯°±²³´µ¶·¸¹º»¼½¾¿ÀÁÂÃÄÅÆÇÈÉÊËÌÍÎÏÐÑÒÓÔÕÖ×ØÙÚÛÜÝÞßàáâãäåæçèéêëìíîïðñòóôõö÷øùúûüýþÿĀāĂăĄąĆćĈĉĊċČčĎďĐđĒēĔĕĖėĘęĚěĜĝĞğĠġĢģĤĥĦħĨĩĪīĬĭĮįİıĲĳĴĵĶķĸĹĺĻļĽľĿŀŁł
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
# ...

# %%
obj2.frame2ascii()
# Out:
# Total frames: 3432
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# c:\Users\acer\Desktop\HW\CV\asg1_ascii_art\.venv\Lib\site-packages\sklearn\decomposition\_pca.py:648: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# ...

# %%
obj2.trim_audio()
# Out:
# Trimmed audio saved as: trimmed_audio.mp3

# %%
obj2.compressVid()
# Out:
# frames : 179
#
#
# First frame number: 300
# Video created successfully!
# Video compressed successfully!

# %%
obj2.vidWithAud()
# Out:
# audio file = trimmed_audio.mp3
#
#
# Video with audio saved as ./bleach_lr/ascii_video/final_video.mp4
